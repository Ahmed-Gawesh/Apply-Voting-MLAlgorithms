# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('F:/AI/Students  Early Attrition.xlsx')
data.head()
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
# 2             7847538         18            M            BGD 1             Y
# 3             8006429         18            M            BGD 1             Y
# 4             7962680         18            F            BGD 1             Y
#
#   INTERNATIONAL_STS  STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N   Undeclared           N                   NaN
# 1                 N   Undeclared           N                  26.0
# 2                 N  Mathematics           N                   NaN
# 3                 N   Undeclared           N                   NaN
# 4                 N          Art           N                   NaN
#
#    STDNT_TEST_ENTRANCE2  ...  DEGREE_GROUP_CD  DEGREE_GROUP_DESC  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   STUDENT IDENTIFIER        3400 non-null   int64
#  1   STDNT_AGE                 3400 non-null   int64
#  2   STDNT_GENDER              3400 non-null   object
#  3   STDNT_BACKGROUND          3400 non-null   object
#  4   IN_STATE_FLAG             3400 non-null   object
#  5   INTERNATIONAL_STS         3400 non-null   object
#  6   STDNT_MAJOR               3400 non-null   object
#  7   STDNT_MINOR               3400 non-null   object
#  8   STDNT_TEST_ENTRANCE1      1106 non-null   float64
#  9   STDNT_TEST_ENTRANCE2      2492 non-null   float64
#  10  STDNT_TEST_ENTRANCE_COMB  2882 non-null   float64
#  11  FIRST_TERM                3400 non-null   int64
#  12  CORE_COURSE_NAME_1_F      3400 non-null   object
# ...

# %%
data.describe()
# Out:
#        STUDENT IDENTIFIER    STDNT_AGE  STDNT_TEST_ENTRANCE1  \
# count        3.400000e+03  3400.000000           1106.000000
# mean         7.897155e+06    17.994118             20.660036
# std          8.083421e+04     0.552052              3.234734
# min          7.755837e+06    16.000000              8.000000
# 25%          7.827039e+06    18.000000             18.000000
# 50%          7.899052e+06    18.000000             20.000000
# 75%          7.964008e+06    18.000000             22.000000
# max          8.037098e+06    26.000000             32.000000
#
#        STDNT_TEST_ENTRANCE2  STDNT_TEST_ENTRANCE_COMB     FIRST_TERM  \
# count           2492.000000               2882.000000    3400.000000
# mean             965.092295                997.758501  200777.000000
# std              209.088633                156.268221     170.001298
# min              350.000000                530.000000  200508.000000
# ...

# %%
data.shape
# Out:
# (3400, 56)

# %%
data.isna().sum()
# Out:
# STUDENT IDENTIFIER             0
# STDNT_AGE                      0
# STDNT_GENDER                   0
# STDNT_BACKGROUND               0
# IN_STATE_FLAG                  0
# INTERNATIONAL_STS              0
# STDNT_MAJOR                    0
# STDNT_MINOR                    0
# STDNT_TEST_ENTRANCE1        2294
# STDNT_TEST_ENTRANCE2         908
# STDNT_TEST_ENTRANCE_COMB     518
# FIRST_TERM                     0
# CORE_COURSE_NAME_1_F           0
# CORE_COURSE_GRADE_1_F          0
# CORE_COURSE_NAME_2_F          99
# CORE_COURSE_GRADE_2_F         99
# CORE_COURSE_NAME_3_F         565
# CORE_COURSE_GRADE_3_F        565
# CORE_COURSE_NAME_4_F        1597
# CORE_COURSE_GRADE_4_F       1597
# CORE_COURSE_NAME_5_F        2755
# CORE_COURSE_GRADE_5_F       2755
# CORE_COURSE_NAME_6_F        3272
# CORE_COURSE_GRADE_6_F       3272
# SECOND_TERM                    0
# CORE_COURSE_NAME_1_S         157
# CORE_COURSE_GRADE_1_S        232
# CORE_COURSE_NAME_2_S         439
# ...

# %% [markdown]
# # Drop Unnecessary Columns

# %%
data.drop(['STDNT_MINOR','STDNT_TEST_ENTRANCE1','STDNT_TEST_ENTRANCE2','CORE_COURSE_NAME_5_F',
       'CORE_COURSE_GRADE_5_F', 'CORE_COURSE_NAME_6_F',
       'CORE_COURSE_GRADE_6_F','CORE_COURSE_NAME_5_S',
       'CORE_COURSE_GRADE_5_S','CORE_COURSE_NAME_6_S',
       'CORE_COURSE_GRADE_6_S','HIGH_SCHL_NAME', 'FATHER_HI_EDU_CD','MOTHER_HI_EDU_CD','CORE_COURSE_NAME_3_F',
       'CORE_COURSE_GRADE_3_F','CORE_COURSE_NAME_3_S',
       'CORE_COURSE_GRADE_3_S','CORE_COURSE_NAME_4_F',
       'CORE_COURSE_GRADE_4_F','CORE_COURSE_NAME_4_S',
       'CORE_COURSE_GRADE_4_S'],axis=1,inplace=True)

# %%
data.isna().sum()
# Out:
# STUDENT IDENTIFIER            0
# STDNT_AGE                     0
# STDNT_GENDER                  0
# STDNT_BACKGROUND              0
# IN_STATE_FLAG                 0
# INTERNATIONAL_STS             0
# STDNT_MAJOR                   0
# STDNT_TEST_ENTRANCE_COMB    518
# FIRST_TERM                    0
# CORE_COURSE_NAME_1_F          0
# CORE_COURSE_GRADE_1_F         0
# CORE_COURSE_NAME_2_F         99
# CORE_COURSE_GRADE_2_F        99
# SECOND_TERM                   0
# CORE_COURSE_NAME_1_S        157
# CORE_COURSE_GRADE_1_S       232
# CORE_COURSE_NAME_2_S        439
# CORE_COURSE_GRADE_2_S       439
# HOUSING_STS                   0
# RETURNED_2ND_YR               0
# DISTANCE_FROM_HOME           25
# HIGH_SCHL_GPA                53
# FATHER_HI_EDU_DESC            0
# MOTHER_HI_EDU_DESC            0
# DEGREE_GROUP_CD               0
# DEGREE_GROUP_DESC             0
# FIRST_TERM_ATTEMPT_HRS        0
# FIRST_TERM_EARNED_HRS         0
# SECOND_TERM_ATTEMPT_HRS     206
# ...

# %% [markdown]
# # Replace & Fill NaN Values

# %%
data.shape
# Out:
# (3400, 34)

# %%
data['FIRST_TERM'].value_counts()
# Out:
# FIRST_TERM
# 200908    676
# 201008    632
# 200808    581
# 200708    521
# 200608    497
# 200508    493
# Name: count, dtype: int64

# %%
data['FIRST_TERM']=data['FIRST_TERM'].replace({200508:2005,200608:2006,200708:2007,200808:2008,200908:2009,201008:2010})

# %%
data["SECOND_TERM"].value_counts()
# Out:
# SECOND_TERM
# 201002    676
# 201102    632
# 200902    581
# 200802    521
# 200702    497
# 200602    493
# Name: count, dtype: int64

# %%
data['FIRST_TERM']=data['FIRST_TERM'].replace({200602:2006,200702:2007,200802:2008,200902:2009,201002:2010,201102:2011})

# %%
data["FIRST_TERM_Hr"]=data['FIRST_TERM_EARNED_HRS']/data['FIRST_TERM_ATTEMPT_HRS']
data["SECOND_TERM_Hr"]=data['SECOND_TERM_EARNED_HRS']/data['SECOND_TERM_ATTEMPT_HRS']

# %%
data.drop(['FIRST_TERM_EARNED_HRS','FIRST_TERM_ATTEMPT_HRS','SECOND_TERM_EARNED_HRS','SECOND_TERM_ATTEMPT_HRS'],axis=1,inplace=True)

# %%
data['CORE_COURSE_NAME_1_F']=data["CORE_COURSE_GRADE_1_F"].str.slice(0,4)
data["CORE_COURSE_NAME_2_F"]=data["CORE_COURSE_NAME_2_F"].str.slice(0,4)

data["CORE_COURSE_NAME_1_S"]=data["CORE_COURSE_NAME_1_S"].str.slice(0,4)
data["CORE_COURSE_NAME_2_S"]=data["CORE_COURSE_NAME_2_S"].str.slice(0,4)

# %%
data['STDNT_TEST_ENTRANCE_COMB']=data['STDNT_TEST_ENTRANCE_COMB'].fillna(data['STDNT_TEST_ENTRANCE_COMB'].mean())

# %%
data[['CORE_COURSE_NAME_2_F','CORE_COURSE_GRADE_2_F']]=data[['CORE_COURSE_NAME_2_F','CORE_COURSE_GRADE_2_F']].fillna(0)
data[['CORE_COURSE_NAME_1_S','CORE_COURSE_GRADE_1_S','CORE_COURSE_NAME_2_S','CORE_COURSE_GRADE_2_S']]=data[['CORE_COURSE_NAME_1_S','CORE_COURSE_GRADE_1_S','CORE_COURSE_NAME_2_S','CORE_COURSE_GRADE_2_S']].fillna(0)

data[['DISTANCE_FROM_HOME','HIGH_SCHL_GPA']]=data[['DISTANCE_FROM_HOME','HIGH_SCHL_GPA']].fillna(data[['DISTANCE_FROM_HOME','HIGH_SCHL_GPA']].mean())

# %%
data['SECOND_TERM_Hr']=data['SECOND_TERM_Hr'].fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   STUDENT IDENTIFIER        3400 non-null   int64
#  1   STDNT_AGE                 3400 non-null   int64
#  2   STDNT_GENDER              3400 non-null   object
#  3   STDNT_BACKGROUND          3400 non-null   object
#  4   IN_STATE_FLAG             3400 non-null   object
#  5   INTERNATIONAL_STS         3400 non-null   object
#  6   STDNT_MAJOR               3400 non-null   object
#  7   STDNT_TEST_ENTRANCE_COMB  3400 non-null   float64
#  8   FIRST_TERM                3400 non-null   int64
#  9   CORE_COURSE_NAME_1_F      3400 non-null   object
#  10  CORE_COURSE_GRADE_1_F     3400 non-null   object
#  11  CORE_COURSE_NAME_2_F      3400 non-null   object
#  12  CORE_COURSE_GRADE_2_F     3400 non-null   object
# ...

# %%
std_return=data['RETURNED_2ND_YR'].value_counts()
std_return
# Out:
# RETURNED_2ND_YR
# 1    2677
# 0     723
# Name: count, dtype: int64

# %%
plt.pie(std_return,autopct='%1.1f%%',labels=std_return.index)
plt.show()

# %% [markdown]
# # Selecting Importance_Features To y Process

# %%
X=data.drop('RETURNED_2ND_YR',axis=1)
y=data['RETURNED_2ND_YR']

# %%
X=pd.get_dummies(X)

# %%
X.head()
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE  STDNT_TEST_ENTRANCE_COMB  FIRST_TERM  \
# 0             7808615         18                    1150.0        2007
# 1             7830063         19                    1190.0        2008
# 2             7847538         18                    1030.0        2010
# 3             8006429         18                    1220.0        2007
# 4             7962680         18                    1190.0        2008
#
#    SECOND_TERM  DISTANCE_FROM_HOME  HIGH_SCHL_GPA  GROSS_FIN_NEED  \
# 0       200802               150.0           4.00               0
# 1       200902                69.0           2.89          570000
# 2       201102               150.0           3.39               0
# 3       200802               150.0           2.93               0
# 4       200902                69.0           3.86          835920
#
#    COST_OF_ATTEND  EST_FAM_CONTRIBUTION  ...  MOTHER_HI_EDU_DESC_High School  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
f=RandomForestClassifier()
f.fit(X,y)

feature_impor=pd.Series(f.feature_importances_,index=X.columns)
feature_impor.nlargest(50).plot(kind='barh')
plt.title('Feature Importances')
plt.show()

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
final_df=scaler.fit_transform(X)

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest,chi2
best_features=SelectKBest(chi2,k=50)
X_selected=best_features.fit_transform(final_df,y)

#Get Feature Names
selected_features=X.columns[best_features.get_support()]
print(selected_features)

# put New Features in Frame 
X_new=X[selected_features]
print(X_new.shape)
# Out:
# Index(['SECOND_TERM_Hr', 'STDNT_BACKGROUND_BGD 1', 'STDNT_BACKGROUND_BGD 3',
#        'STDNT_BACKGROUND_BGD 5', 'IN_STATE_FLAG_N', 'INTERNATIONAL_STS_Y',
#        'STDNT_MAJOR_Biology and Secondary Ed',
#        'STDNT_MAJOR_Computer Science - Games', 'STDNT_MAJOR_Criminal Justice',
#        'STDNT_MAJOR_Joint Enrollment - Accel', 'STDNT_MAJOR_Music Education',
#        'STDNT_MAJOR_Music Performance', 'STDNT_MAJOR_Psychology',
#        'STDNT_MAJOR_Theatre Arts', 'CORE_COURSE_NAME_1_F_B',
#        'CORE_COURSE_NAME_1_F_D', 'CORE_COURSE_NAME_1_F_F',
#        'CORE_COURSE_GRADE_1_F_B', 'CORE_COURSE_GRADE_1_F_D',
#        'CORE_COURSE_GRADE_1_F_F', 'CORE_COURSE_NAME_2_F_POLS',
#        'CORE_COURSE_GRADE_2_F_A', 'CORE_COURSE_GRADE_2_F_B',
#        'CORE_COURSE_GRADE_2_F_C', 'CORE_COURSE_GRADE_2_F_D',
#        'CORE_COURSE_GRADE_2_F_F', 'CORE_COURSE_NAME_1_S_0',
#        'CORE_COURSE_NAME_1_S_ENGL', 'CORE_COURSE_NAME_1_S_MATH',
# ...

# %% [markdown]
# # Spliting Data and build Models

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.2,shuffle=True,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,VotingClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,cross_val_score
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

models={
    "Logistic Regression":LogisticRegression(),
    "SVM":SVC(),
    "Decision Tree":DecisionTreeClassifier(),
    "naive bayes":GaussianNB()
}
ensemble_models={
    "Random Forest":RandomForestClassifier(),
    'Gradient Boosting':GradientBoostingClassifier(),
}

params={
    "Logistic Regression":{'C':[0.01,0.1,1,10]},
    "SVM":{ 'kernel':['rbf','linear'],'C':[0.01,0.1,1,10] },
    "Decision Tree":{'criterion':['gini','entropy'],'max_depth':[3,5,10]},
    "naive bayes":{},
    "Random Forest":{'n_estimators':[100,150,200]},
    'Gradient Boosting':{'n_estimators':[100,150,200]},
}

# %%
#Model Evaluation
cv=StratifiedKFold(n_splits=5,random_state=0,shuffle=True)

best_models={}
# For Models 
for name, model in models.items():
    grid_search=GridSearchCV(model,params[name],cv=cv,scoring='accuracy')
    grid_search.fit(X_train,y_train)
    best_models[name]=grid_search.best_estimator_
    print(f"{name}: best parameters :{grid_search.best_params_} ,Best Score:{grid_search.best_score_} ")

# For Ensemble Models
for name, model in ensemble_models.items():
    grid_search=GridSearchCV(model,params[name],cv=cv,scoring="accuracy")
    grid_search.fit(X_train,y_train)
    best_models[name]=grid_search.best_estimator_
    print(f"{name}: best parameters :{grid_search.best_params_} ,Best Score:{grid_search.best_score_} ")

#--------------------------------------------------------
# Voting Method

estimators=[('rf',best_models['Random Forest']),('nb',best_models['naive bayes'])]
voting_clf=VotingClassifier(estimators=estimators, voting='soft')
voting_clf.fit(X_train,y_train)
best_models['Voting']=voting_clf

#---------------------------------------------------------
#Evaluate Best Model
for name,model in best_models.items():
    y_pred=model.predict(X_test)
    acc_score=accuracy_score(y_test,y_pred)
    report=classification_report(y_test,y_pred)
    cm=confusion_matrix(y_test,y_pred)
    print(f"Name: {name}")
    print(f"Confusion Metrix: {cm}")
    print(f"Accuracy: {acc_score}")
    print(f"Report: {report}")
# Out:
# Logistic Regression: best parameters :{'C': 10} ,Best Score:0.8345588235294118
# SVM: best parameters :{'C': 10, 'kernel': 'linear'} ,Best Score:0.8316176470588236
# Decision Tree: best parameters :{'criterion': 'gini', 'max_depth': 3} ,Best Score:0.8279411764705882
# naive bayes: best parameters :{} ,Best Score:0.7948529411764707
# Random Forest: best parameters :{'n_estimators': 100} ,Best Score:0.8047794117647058
# Gradient Boosting: best parameters :{'n_estimators': 100} ,Best Score:0.83125
# Name: Logistic Regression
# Confusion Metrix: [[ 36  93]
#  [ 15 536]]
# Accuracy: 0.8411764705882353
# Report:               precision    recall  f1-score   support
#
#            0       0.71      0.28      0.40       129
#            1       0.85      0.97      0.91       551
#
#     accuracy                           0.84       680
#    macro avg       0.78      0.63      0.65       680
# weighted avg       0.82      0.84      0.81       680
#
# Name: SVM
# Confusion Metrix: [[ 31  98]
# ...

# %%
from sklearn.naive_bayes import GaussianNB
